# %%
#Question 01:

strr = input("Enter a string: ")
vovel = ['a','e','i','o','u']
result = []

for letter in vovel:
    if letter in strr:
        result.append(letter)

print("vovel",result)
print("count", len(result))

# %%
#Question-02:

input_string = input("Enter a string: ")
uppercase_count = 0
lowercase_count = 0
digit_count = 0
whitespace_count = 0


for char in input_string:
    if char.isupper():
        uppercase_count += 1
    elif char.islower():
        lowercase_count += 1
    elif char.isdigit():
        digit_count += 1
    elif char.isspace():
        whitespace_count += 1

print(f"Number of uppercase letters: {uppercase_count}")
print(f"Number of lowercase letters: {lowercase_count}")
print(f"Number of digits: {digit_count}")
print(f"Number of whitespace characters: {whitespace_count}")
# Out:
# Number of uppercase letters: 2
# Number of lowercase letters: 9
# Number of digits: 0
# Number of whitespace characters: 2

# %%
#Question-03:

input_string = input("Enter a string: ")
if len(input_string) < 2:
    print("String must have at least two characters.")
else:
  
    new_string = input_string[-1] + input_string[1:-1] + input_string[0]
    print(f"The new string is: {new_string}")
# Out:
# The new string is: ysman is good boU

# %%
#Question-04:


input_string = input("Enter a string: ")

reversed_string = input_string[::-1]

print(f"The reversed string is: {reversed_string}")
# Out:
# The reversed string is: namsU

# %%
#Question-05:

input_string = input("Enter a string: ")

if len(input_string) == 0:
    print("The string is empty.")
else:
    shifted_string = input_string[1:] + input_string[0]
    print(f"The string after shifting one position to the left is: {shifted_string}")
# Out:
# The string after shifting one position to the left is: y name is UsmanM

# %%
#Question-06:

full_name = input("Enter your full name (First Middle Last): ")
initials = ""

if full_name[0].isalpha():
    initials += full_name[0].upper()

for i in range(len(full_name)):

    if full_name[i] == ' ' and i + 1 < len(full_name):
        initials += full_name[i + 1].upper()

print(f"Your initials are: {initials}")
# Out:
# Your initials are: MUH

# %%
#Question-07:

input_string = input("Enter a string: ")
cleaned_string = input_string.replace(" ", "").lower()
start = 0
end = len(cleaned_string) - 1
is_palindrome = True

while start < end:
    if cleaned_string[start] != cleaned_string[end]:
        is_palindrome = False
        break
    start += 1
    end -= 1

if is_palindrome:
    print(f"'{input_string}' is a palindrome.")
else:
    print(f"'{input_string}' is not a palindrome.")
# Out:
# 'hint' is not a palindrome.

# %%
#Question-08:

from itertools import permutations, islice

word = 'SHIFT'
combinations = permutations(word)

for combo in islice(combinations, 10):
    print(''.join(combo))

# %%
#Question-09:

import re

def validate_password(password):
    if (len(password) >= 8 and re.search(r'[A-Z]', password) and re.search(r'[a-z]', password) and re.search(r'\d', password)):         
        return True
    else:
        return False

password = input("Enter a password: ")
if validate_password(password):
    print("Password is valid.")
else:
    print("Password must be at least 8 characters long, contain uppercase and lowercase letters, and have at least one digit.")
# Out:
# Password is valid.
